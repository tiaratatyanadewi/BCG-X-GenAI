# %% [markdown]
# <a href="https://colab.research.google.com/github/tiaratatyanadewi/BCG-X-GenAI/blob/main/Task_2_BCG_X_Gen_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Building Financial Chatbot

# %%
# !gdown 1KWMDiSuw6qSdgLeDKl7UKACmREolV1ty
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KWMDiSuw6qSdgLeDKl7UKACmREolV1ty
# To: /content/final_data.csv
# 100% 2.46k/2.46k [00:00<00:00, 6.74MB/s]

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 484.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 53.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('final_data.csv')

# %%
df
# Out:
#      Company  Year  Total Revenue   Net Income  Total Assets  \
# 0  Microsoft  2023   211915000000  72361000000  411976000000
# 1  Microsoft  2022   198270000000  72738000000  364840000000
# 2  Microsoft  2021   168088000000  61271000000  333779000000
# 3      Tesla  2023    96773000000  14974000000  106618000000
# 4      Tesla  2022    81462000000  12587000000   82338000000
# 5      Tesla  2021    53823000000   5644000000   62131000000
# 6      Apple  2023   383285000000  96995000000  352583000000
# 7      Apple  2022   394328000000  99803000000  352755000000
# 8      Apple  2021   365817000000  94680000000  351022000000
#
#    Total Liabilities     Cash Flow  Revenue Growth (%)  Net Income Growth (%)  \
# 0       205753000000   87582000000            0.000000               0.000000
# 1       198298000000   89035000000           -6.438902               0.520999
# 2       191791000000   76740000000          -15.222676             -15.764800
# ...

# %%
def generate_qa_list():
    questions = []
    answers = []

    for i in range(len(df["Company"])):
        questions.append(f"What is the Total Revenue of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Total Revenue'][i]:,.0f}")

        questions.append(f"What is the Net Income of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Net Income'][i]:,.0f}")

        questions.append(f"What are the Total Assets of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Total Assets'][i]:,.0f}")

        questions.append(f"What are the Total Liabilities of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Total Liabilities'][i]:,.0f}")

        questions.append(f"What is the Cash Flow of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Cash Flow'][i]:,.0f}")

        questions.append(f"What is the Revenue Growth (%) of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"{df['Revenue Growth (%)'][i]:,.6f}%")

        questions.append(f"What is the Net Income Growth (%) of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"{df['Net Income Growth (%)'][i]:,.6f}%")

        questions.append(f"What is the Liabilities to Assets ratio of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"{df['Liabilities_to_Assets'][i]:,.6f}")

        questions.append(f"What is the Net Income to Revenue ratio of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"{df['Net_Income_to_Revenue'][i]:,.6f}")

        questions.append(f"What is the Revenue Growth Rate of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"{df['Revenue_Growth_Rate'][i]:,.6f}")

        questions.append(f"What is the Net Income Growth Rate of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"{df['Net_Income_Growth_Rate'][i]:,.6f}")

        questions.append(f"What is the Revenue Rolling Mean of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Revenue_Rolling_Mean'][i]:,.0f}" if df['Revenue_Rolling_Mean'][i] is not None else "0")

        questions.append(f"What is the Revenue Rolling Std of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Revenue_Rolling_Std'][i]:,.0f}" if df['Revenue_Rolling_Std'][i] is not None else "0")

        questions.append(f"What is the Net Income Rolling Mean of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Net_Income_Rolling_Mean'][i]:,.0f}" if df['Net_Income_Rolling_Mean'][i] is not None else "0")

        questions.append(f"What is the Net Income Rolling Std of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Net_Income_Rolling_Std'][i]:,.0f}" if df['Net_Income_Rolling_Std'][i] is not None else "0")

        questions.append(f"What is the Revenue Lag 1 of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Revenue_Lag_1'][i]:,.0f}" if df['Revenue_Lag_1'][i] is not None else "0")

        questions.append(f"What is the Net Income Lag 1 of {df['Company'][i]} in {df['Year'][i]}?")
        answers.append(f"${df['Net_Income_Lag_1'][i]:,.0f}" if df['Net_Income_Lag_1'][i] is not None else "0")

    qa_df = pd.DataFrame({"Question": questions, "Answer": answers})

    return qa_df

# %%
qa_df = generate_qa_list()
qa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Question  153 non-null    object
#  1   Answer    153 non-null    object
# dtypes: object(2)
# memory usage: 2.5+ KB

# %%
qa_df
# Out:
#                                               Question            Answer
# 0      What is the Total Revenue of Microsoft in 2023?  $211,915,000,000
# 1         What is the Net Income of Microsoft in 2023?   $72,361,000,000
# 2      What are the Total Assets of Microsoft in 2023?  $411,976,000,000
# 3    What are the Total Liabilities of Microsoft in...  $205,753,000,000
# 4          What is the Cash Flow of Microsoft in 2023?   $87,582,000,000
# ..                                                 ...               ...
# 148  What is the Revenue Rolling Std of Apple in 2021?   $20,160,321,438
# 149  What is the Net Income Rolling Mean of Apple i...   $97,241,500,000
# 150  What is the Net Income Rolling Std of Apple in...    $3,622,508,040
# 151        What is the Revenue Lag 1 of Apple in 2021?  $394,328,000,000
# 152     What is the Net Income Lag 1 of Apple in 2021?   $99,803,000,000
#
# [153 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
qa_df.isnull().sum()
# Out:
# Question    0
# Answer      0
# dtype: int64

# %%
vec = TfidfVectorizer()
vec.fit(np.concatenate((qa_df['Question'], qa_df['Answer'])))
# Out:
# TfidfVectorizer()

# %%
feature_col = vec.get_feature_names_out()
len(feature_col)
# Out:
# 217

# %%
df_vectors = vec.transform(qa_df['Question'])

# %%
df_vectors
# Out:
# <153x217 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1521 stored elements in Compressed Sparse Row format>

# %%
import gradio as gr
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Sample function to process input and return the chatbot's response
def chatbot_response(input_question):
    input_question_vec = vec.transform([input_question])
    similarity = cosine_similarity(input_question_vec, df_vectors)
    closest_ans = np.argmax(similarity, axis=1)

    # Check if the similarity is below a certain threshold
    max_similarity = similarity[0][closest_ans[0]]
    if max_similarity < 0.1:  # Adjust this threshold as needed
        response = "Sorry, we found no data related to that question."
    else:
        response = qa_df['Answer'].iloc[closest_ans].values[0]

    return response

# Gradio interface
def gradio_interface():
    gr.Interface(
        fn=chatbot_response,
        inputs="text",
        outputs="text",
        title="BCG X Financial Chatbot Demo",
        description="Hello, welcome to BCG X Financial Chatbot Demo. Ask me anything you want.",
        live=True
    ).launch()

# Launch the Gradio UI
gradio_interface()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://c095af9f501fc8e1b8.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c095af9f501fc8e1b8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
